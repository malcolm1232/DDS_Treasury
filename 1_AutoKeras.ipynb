# %%
import numpy as np
import pandas as pd
import tensorflow as tf

import autokeras as ak

TRAIN_DATA_URL = "https://storage.googleapis.com/tf-datasets/titanic/train.csv"
TEST_DATA_URL = "https://storage.googleapis.com/tf-datasets/titanic/eval.csv"

train_file_path = tf.keras.utils.get_file("train.csv", TRAIN_DATA_URL)
test_file_path = tf.keras.utils.get_file("eval.csv", TEST_DATA_URL)

main_path = 'C:/Users/malco/aaPythonPersonalNotebook/DBS Data Scientist Treasury and Market Operations/dataset/'
path_train = 'adult_data_RenameCol_MinMax_LE.csv'
path_test = 'adult_test_RenameCol_MinMax_LE.csv'
train_filepath = main_path + path_train
test_filepath = main_path + path_test

# df = pd.read_csv(train_filepath, index_col = 0)

# Initialize the structured data classifier.
clf = ak.StructuredDataClassifier(
    overwrite=True, max_trials=3
)  # It tries 3 different models.
# Feed the structured data classifier with training data.
clf.fit(
    # The path to the train.csv file.
    train_filepath,
    # The name of the label column.
    "class",
    epochs=10,
    verbose=0
)
# Predict with the best model.
predicted_y = clf.predict(test_filepath)
# Evaluate the best model with testing data.
evaled = clf.evaluate(test_filepath, "class")
print("evaled:",evaled)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c87b8f9b8f1d> in <module>
#      30     "class",
#      31     epochs=10,
# ---> 32     verbose=0
#      33 )
#      34 # Predict with the best model.
#
# c:\users\malco\appdata\local\programs\python\python36\lib\site-packages\autokeras\tasks\structured_data.py in fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     320             validation_split=validation_split,
#     321             validation_data=validation_data,
# --> 322             **kwargs
#     323         )
#     324
#
# c:\users\malco\appdata\local\programs\python\python36\lib\site-packages\autokeras\tasks\structured_data.py in fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     139             validation_split=validation_split,
#     140             validation_data=validation_data,
# ...
